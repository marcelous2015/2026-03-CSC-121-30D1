# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelous2015/2026-03-CSC-121-30D1/blob/main/3%3CWEEK_professional_bio_week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Professional Bio Generator

# Variables
name = "Jordan"
goal = "become a software developer"
birth_year = 2004
current_year = 2026

# Calculation
age = current_year - birth_year

# Logic / Pseudocode
# 1. Assign values to name, goal, birth_year, and current_year.
# 2. Calculate age by subtracting birth_year from current_year.
# 3. Print the top border using string multiplication.
# 4. Print the professional bio.
# 5. Print the bottom border using string multiplication.
