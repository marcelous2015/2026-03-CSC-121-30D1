# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelous2015/2026-03-CSC-121-30D1/blob/main/3%3DWEEK/professional_bio_week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Professional Bio Generator

# Variables
name = "Jordan"
goal = "become a software developer"
birth_year = 2004
current_year = 2026

# Calculate age
age = current_year - birth_year

# Logic / Pseudocode
# 1. Assign values to name, goal, birth_year, and current_year.
# 2. Calculate age by subtracting birth_year from current_year.
# 3. Print a 25-character border.
# 4. Print the bio sentences.
# 5. Print another 25-character border.

# %%
# Professional Bio Generator

# Variables
name = "Jordan"
goal = "become a software developer"
birth_year = 2004
current_year = 2026

# Calculate age
age = current_year - birth_year

# Top border
print("=" * 25)

# First bio sentence
print("My name is", name, "and I am", age, "years old.")
# Out:
# ...
# My name is Jordan and I am 22 years old.

# %%
# Professional Bio Generator

# Variables
name = "Jordan"
goal = "become a software developer"
birth_year = 2004
current_year = 2026

# Calculate age
age = current_year - birth_year

# Create a 25-character border
border = "=" * 25

# Display professional bio
print(border)
print("My name is", name, "and I am", age, "years old.")
print("My goal is to", goal + ".")
print(border)
# Out:
# ...
# My name is Jordan and I am 22 years old.
# My goal is to become a software developer.
# ...
