# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelous2015/2026-03-CSC-121-30D1/blob/main/3%40WEEK/professional_bio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Professional Bio Generator
# Week 3 Assignment

# STRUCTURE & PSEUDOCODE
# 1. Assign values to name, goal, birth_year, and current_year.
# 2. Calculate age by subtracting birth_year from current_year.
# 3. Create a border that is exactly 25 characters long using string multiplication.
# 4. Print the top border.
# 5. Print the bio sentences.
# 6. Print the bottom border.

# %%
name = "Jordan"
goal = "become a software developer"
birth_year = 2004
current_year = 2026

age = current_year - birth_year

border = "=" * 25

print(border)
print("My name is " + name + " and I am " + str(age) + " years old.")
# Out:
# ...
# My name is Jordan and I am 22 years old.

# %%
name = "Jordan"
goal = "become a software developer"
birth_year = 2004
current_year = 2026

age = current_year - birth_year

border = "=" * 25

print(border)
print("My name is " + name + " and I am " + str(age) + " years old.")
print("My goal is to " + goal + ".")
print(border)
# Out:
# ...
# My name is Jordan and I am 22 years old.
# My goal is to become a software developer.
# ...
